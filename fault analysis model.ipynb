# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, PolynomialFeatures
from xgboost import XGBRegressor 
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
import logging
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List
from utils import FeatureEngineer
from scipy import stats

# %%
# Setup logging
logging.basicConfig(
    filename='model_training.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filemode='w'
)
logging.info('Training started on %s', pd.Timestamp.now())

# Load data
try:
    df: pd.DataFrame = pd.read_csv('Health_index1.csv')
    df.columns = df.columns.str.strip()
    logging.info(f'Loaded Health_index1.csv. Shape: {df.shape}')
except FileNotFoundError:
    logging.error('Health_index1.csv not found.')
    raise

# %%
# Feature engineering
df = FeatureEngineer.add_gas_ratios(df)
df = FeatureEngineer.add_log_features(df)

# Add Doernenburg and Rogers ratios
df['CH4_H2_ratio'] = df['Methane'] / (df['Hydrogen'] + 1)
df['C2H2_C2H4_ratio'] = df['Acetylene'] / (df['Ethylene'] + 1)
df['C2H2_CH4_ratio'] = df['Acetylene'] / (df['Methane'] + 1)
df['C2H6_C2H2_ratio'] = df['Ethane'] / (df['Acetylene'] + 1)

# Add gas percentages and concentrations
df['Total_Gases'] = df[['Hydrogen', 'Methane', 'CO', 'CO2', 'Ethylene', 'Ethane', 'Acetylene']].sum(axis=1)
df['H2_percent'] = df['Hydrogen'] / df['Total_Gases'] * 100
df['CH4_percent'] = df['Methane'] / df['Total_Gases'] * 100
df['CO_percent'] = df['CO'] / df['Total_Gases'] * 100
df['CO2_percent'] = df['CO2'] / df['Total_Gases'] * 100
df['Gas_Concentration'] = df['Total_Gases'] / 1000000

# Add quality indicator interactions
df['Gas_DBDS_interaction'] = df['Total_Gases'] * df['DBDS']
df['Gas_Water_interaction'] = df['Total_Gases'] * df['Water content']
df['Power_Gas_interaction'] = df['Total_Gases'] * df['Power factor']

# Add binned features
df['H2_level'] = pd.qcut(df['Hydrogen'], q=5, labels=['VL', 'L', 'M', 'H', 'VH'])
df['Gas_level'] = pd.qcut(df['Total_Gases'], q=5, labels=['VL', 'L', 'M', 'H', 'VH'])
df['Water_level'] = pd.qcut(df['Water content'], q=5, labels=['VL', 'L', 'M', 'H', 'VH'])

# Convert categorical to dummy variables
df = pd.get_dummies(df, columns=['H2_level', 'Gas_level', 'Water_level'])

# Add polynomial features
gas_cols = ['Hydrogen', 'Methane', 'CO', 'CO2', 'Ethylene']
poly = PolynomialFeatures(degree=2, include_bias=False)
poly_features = poly.fit_transform(df[gas_cols])
poly_feature_names = [f'Poly_{i}' for i in range(poly_features.shape[1])]
df_poly = pd.DataFrame(poly_features, columns=poly_feature_names)

# Combine all features
df = pd.concat([df, df_poly], axis=1)

# Define features for regression
regression_features: List[str] = [
    'Hydrogen', 'Oxigen', 'Nitrogen', 'Methane', 'CO', 'CO2', 'Ethylene',
    'Ethane', 'Acetylene', 'DBDS', 'Power factor', 'Interfacial V',
    'Dielectric rigidity', 'Water content',
    'CH4_H2_ratio', 'C2H2_C2H4_ratio', 'C2H2_CH4_ratio', 'C2H6_C2H2_ratio',
    'H2_percent', 'CH4_percent', 'CO_percent', 'CO2_percent',
    'Gas_Concentration', 'Gas_DBDS_interaction', 'Gas_Water_interaction',
    'Power_Gas_interaction'
]

# Verify no target variables are in features
assert 'Health_index' not in regression_features, "Health_index should not be a feature"
assert 'Life_expectation' not in regression_features, "Life_expectation should not be a feature"

# Add dummy variable columns
level_columns = [col for col in df.columns if col.endswith('_VL') or 
                                            col.endswith('_L') or 
                                            col.endswith('_M') or 
                                            col.endswith('_H') or 
                                            col.endswith('_VH')]
regression_features.extend(level_columns)
regression_features.extend(poly_feature_names)

# Remove outliers function
def remove_outliers(X, y, z_threshold=3):
    z_scores = np.abs(stats.zscore(X))
    mask = (z_scores < z_threshold).all(axis=1)
    return X[mask], y[mask]

# Prepare and clean regression data
X_health: pd.DataFrame = df[regression_features].fillna(0.0)
y_health: pd.Series = df['Health_index'].astype(float)
X_life: pd.DataFrame = df[regression_features].fillna(0.0)
y_life: pd.Series = df['Life_expectation'].astype(float)

# Convert boolean columns to float to avoid dtype issues in zscore
for col in X_health.select_dtypes(include=['bool']).columns:
    X_health[col] = X_health[col].astype(float)
for col in X_life.select_dtypes(include=['bool']).columns:
    X_life[col] = X_life[col].astype(float)

# Remove outliers
X_health_clean, y_health_clean = remove_outliers(X_health, y_health)
X_life_clean, y_life_clean = remove_outliers(X_life, y_life)

# Scale features using RobustScaler
scaler = RobustScaler()
X_health_scaled = scaler.fit_transform(X_health_clean)
X_life_scaled = scaler.transform(X_life_clean)

# %%
# Scale features
scaler: StandardScaler = StandardScaler()
X_health_scaled: np.ndarray = scaler.fit_transform(X_health)
X_life_scaled: np.ndarray = scaler.transform(X_life)
joblib.dump(scaler, 'scaler_fitted_on_full_data.gz')
logging.info('Saved scaler.')

# Split data
X_health_train: np.ndarray
X_health_test: np.ndarray
y_health_train: pd.Series
y_health_test: pd.Series
X_health_train, X_health_test, y_health_train, y_health_test = train_test_split(
    X_health_scaled, y_health, test_size=0.2, random_state=42
)
X_life_train: np.ndarray
X_life_test: np.ndarray
y_life_train: pd.Series
y_life_test: pd.Series
X_life_train, X_life_test, y_life_train, y_life_test = train_test_split(
    X_life_scaled, y_life, test_size=0.2, random_state=42
)
logging.info(f'Training set sizes: Health: {X_health_train.shape}, Life: {X_life_train.shape}')

# %%
"""# Feature selection using feature importance
def select_top_features(model, feature_names, threshold=0.01):  # Increased threshold
    importance = model.feature_importances_
    selected = [i for i, imp in enumerate(importance) if imp > threshold]
    return [feature_names[i] for i in selected], selected

# Define optimized XGBoost parameters with more conservative settings
xgb_params = {
    'n_estimators': 1500,       # Balanced for current features
    'max_depth': 4,             # Slightly increased
    'learning_rate': 0.01,      # Kept moderate
    'min_child_weight': 5,      # Balanced
    'subsample': 0.8,           # Increased for stability
    'colsample_bytree': 0.8,    # Increased for better feature use
    'gamma': 0.1,               # Reduced for better splits
    'reg_alpha': 0.2,           # Reduced L1 regularization
    'reg_lambda': 1.0,          # Moderate L2 regularization
    'random_state': 42,
    'tree_method': 'hist',      
    'objective': 'reg:squarederror',
    'max_leaves': 24            # Increased for better learning
}

# Train initial model for feature selection
initial_health_model = XGBRegressor(**xgb_params)
initial_health_model.fit(X_health_train, y_health_train)

# Select important features
top_features, feature_idx = select_top_features(initial_health_model, regression_features)
logging.info(f'Selected {len(top_features)} important features')

# Train final models with selected features
X_health_train_selected = X_health_train[:, feature_idx]
X_health_test_selected = X_health_test[:, feature_idx]
X_life_train_selected = X_life_train[:, feature_idx]
X_life_test_selected = X_life_test[:, feature_idx]

# Train Health_index regressor
health_model = XGBRegressor(**xgb_params)
health_model.fit(
    X_health_train_selected, 
    y_health_train,
    eval_set=[(X_health_train_selected, y_health_train), 
              (X_health_test_selected, y_health_test)],
    verbose=True
)

# Train Life_expectation regressor
life_model = XGBRegressor(**xgb_params)
life_model.fit(
    X_life_train_selected, 
    y_life_train,
    eval_set=[(X_life_train_selected, y_life_train), 
              (X_life_test_selected, y_life_test)],
    verbose=True
)

# Evaluate models
health_pred = health_model.predict(X_health_test_selected)
health_mse = mean_squared_error(y_health_test, health_pred)
health_cv_mse = -cross_val_score(
    health_model, X_health_train_selected, y_health_train, 
    cv=5, 
    scoring='neg_mean_squared_error'
)

life_pred = life_model.predict(X_life_test_selected)
life_mse = mean_squared_error(y_life_test, life_pred)
life_cv_mse = -cross_val_score(
    life_model, X_life_train_selected, y_life_train, 
    cv=5, 
    scoring='neg_mean_squared_error'
)""""fault analysis model.ipynb"

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Updated feature selection with stricter threshold
def select_top_features(model, feature_names, threshold=0.02):  # Increased threshold
    importance = model.feature_importances_
    selected = [i for i, imp in enumerate(importance) if imp > threshold]
    selected_features = [feature_names[i] for i in selected]
    
    logging.info(f"Selected features with importance > {threshold}")
    for feat, imp in zip(selected_features, importance[selected]):
        logging.info(f"Feature: {feat}, Importance: {imp:.4f}")
    
    return selected_features, selected

# Optimized XGBoost parameters based on feature importance
xgb_params = {
    'n_estimators': 200,       # Increased for better convergence
    'max_depth': 4,             # Kept moderate to prevent overfitting
    'learning_rate': 0.01,     # Reduced for better generalization
    'min_child_weight': 7,      # Increased to prevent overfitting
    'subsample': 0.7,           # Reduced to prevent overfitting
    'colsample_bytree': 0.7,    # Reduced to focus on important features
    'gamma': 0.1,               # Increased for more conservative splits
    'reg_alpha': 0.4,           # Increased L1 regularization
    'reg_lambda': 1.5,          # Increased L2 regularization
    'random_state': 42,
    'tree_method': 'hist',
    'objective': 'reg:squarederror',
    'max_leaves': 24            # Reduced to prevent overfitting
}

# Create focused feature interactions
def create_focused_interactions(df):
    return pd.DataFrame({
        'DBDS_Acetylene': df['DBDS'] * df['Acetylene'],
        'Methane_Acetylene': df['Methane'] * df['Acetylene'],
        'DBDS_Gas_Ratio': df['DBDS'] / (df['Total_Gases'] + 1),
        'Acetylene_Ratio': df['Acetylene'] / (df['Total_Gases'] + 1)
    })

# Model evaluation function with detailed metrics
def evaluate_model(model, X_train, X_test, y_train, y_test, model_name):
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    cv_scores = -cross_val_score(
        model, X_train, y_train,
        cv=5,
        scoring='neg_mean_squared_error'
    )
    
    logging.info(f"\n{model_name} Performance Metrics:")
    logging.info(f"MSE (Test): {mse:.4f}")
    logging.info(f"RMSE (Test): {rmse:.4f}")
    logging.info(f"MAE (Test): {mae:.4f}")
    logging.info(f"R² Score: {r2:.4f}")
    logging.info(f"CV MSE: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
    
    return mse, cv_scores

# Train and evaluate models
initial_health_model = XGBRegressor(**xgb_params)
initial_health_model.fit(X_health_train, y_health_train)

# Select features and train final models
top_features, feature_idx = select_top_features(initial_health_model, regression_features)
X_health_train_selected = X_health_train[:, feature_idx]
X_health_test_selected = X_health_test[:, feature_idx]
X_life_train_selected = X_life_train[:, feature_idx]
X_life_test_selected = X_life_test[:, feature_idx]

# Train final models
health_model = XGBRegressor(**xgb_params)
health_model.fit(
    X_health_train_selected, 
    y_health_train,
    eval_set=[(X_health_train_selected, y_health_train), 
              (X_health_test_selected, y_health_test)],
    verbose=True
)

life_model = XGBRegressor(**xgb_params)
life_model.fit(
    X_life_train_selected, 
    y_life_train,
    eval_set=[(X_life_train_selected, y_life_train), 
              (X_life_test_selected, y_life_test)],
    verbose=True
)

# Evaluate final models
health_metrics = evaluate_model(
    health_model, X_health_train_selected, X_health_test_selected,
    y_health_train, y_health_test, "Health Index"
)

life_metrics = evaluate_model(
    life_model, X_life_train_selected, X_life_test_selected,
    y_life_train, y_life_test, "Life Expectation"
)
# Out:
# [0]	validation_0-rmse:17.39067	validation_1-rmse:18.48817
# [1]	validation_0-rmse:17.27327	validation_1-rmse:18.36746
# [2]	validation_0-rmse:17.15863	validation_1-rmse:18.24114
# [3]	validation_0-rmse:17.06207	validation_1-rmse:18.15179
# [4]	validation_0-rmse:16.94515	validation_1-rmse:18.03704
# [5]	validation_0-rmse:16.83014	validation_1-rmse:17.92664
# [6]	validation_0-rmse:16.73397	validation_1-rmse:17.82242
# [7]	validation_0-rmse:16.63262	validation_1-rmse:17.72035
# [8]	validation_0-rmse:16.53427	validation_1-rmse:17.61362
# [9]	validation_0-rmse:16.42947	validation_1-rmse:17.50932
# [10]	validation_0-rmse:16.32238	validation_1-rmse:17.39498
# [11]	validation_0-rmse:16.21656	validation_1-rmse:17.28469
# [12]	validation_0-rmse:16.11675	validation_1-rmse:17.19627
# [13]	validation_0-rmse:16.01859	validation_1-rmse:17.10132
# [14]	validation_0-rmse:15.91723	validation_1-rmse:16.99488
# [15]	validation_0-rmse:15.82442	validation_1-rmse:16.91320
# [16]	validation_0-rmse:15.73084	validation_1-rmse:16.83293
# [17]	validation_0-rmse:15.63669	validation_1-rmse:16.74048
# [18]	validation_0-rmse:15.54080	validation_1-rmse:16.64300
# [19]	validation_0-rmse:15.44907	validation_1-rmse:16.55234
# [20]	validation_0-rmse:15.35679	validation_1-rmse:16.45828
# [21]	validation_0-rmse:15.26203	validation_1-rmse:16.37014
# [22]	validation_0-rmse:15.17237	validation_1-rmse:16.27369
# [23]	validation_0-rmse:15.08171	validation_1-rmse:16.18534
# [24]	validation_0-rmse:14.99333	validation_1-rmse:16.10920
# [25]	validation_0-rmse:14.90357	validation_1-rmse:16.01379
# [26]	validation_0-rmse:14.81977	validation_1-rmse:15.93368
# [27]	validation_0-rmse:14.73299	validation_1-rmse:15.83938
# [28]	validation_0-rmse:14.64002	validation_1-rmse:15.75122
# [29]	validation_0-rmse:14.55361	validation_1-rmse:15.66866
# [30]	validation_0-rmse:14.47453	validation_1-rmse:15.58349
# [31]	validation_0-rmse:14.39733	validation_1-rmse:15.51970
# [32]	validation_0-rmse:14.31458	validation_1-rmse:15.43652
# [33]	validation_0-rmse:14.23569	validation_1-rmse:15.36497
# [34]	validation_0-rmse:14.15965	validation_1-rmse:15.29499
# [35]	validation_0-rmse:14.08687	validation_1-rmse:15.23032
# [36]	validation_0-rmse:14.01204	validation_1-rmse:15.17289
# [37]	validation_0-rmse:13.93454	validation_1-rmse:15.09446
# [38]	validation_0-rmse:13.85464	validation_1-rmse:15.01362
# [39]	validation_0-rmse:13.78200	validation_1-rmse:14.94319
# [40]	validation_0-rmse:13.70948	validation_1-rmse:14.86916
# [41]	validation_0-rmse:13.64142	validation_1-rmse:14.79775
# [42]	validation_0-rmse:13.56753	validation_1-rmse:14.72709
# [43]	validation_0-rmse:13.49615	validation_1-rmse:14.66076
# [44]	validation_0-rmse:13.42756	validation_1-rmse:14.59385
# [45]	validation_0-rmse:13.35981	validation_1-rmse:14.53242
# [46]	validation_0-rmse:13.29174	validation_1-rmse:14.45508
# [47]	validation_0-rmse:13.22140	validation_1-rmse:14.37888
# [48]	validation_0-rmse:13.15264	validation_1-rmse:14.31535
# [49]	validation_0-rmse:13.08640	validation_1-rmse:14.24987
# [50]	validation_0-rmse:13.02671	validation_1-rmse:14.19603
# [51]	validation_0-rmse:12.95696	validation_1-rmse:14.12746
# [52]	validation_0-rmse:12.89234	validation_1-rmse:14.05569
# [53]	validation_0-rmse:12.82598	validation_1-rmse:13.98937
# [54]	validation_0-rmse:12.76119	validation_1-rmse:13.93909
# [55]	validation_0-rmse:12.70348	validation_1-rmse:13.87298
# [56]	validation_0-rmse:12.64184	validation_1-rmse:13.80302
# [57]	validation_0-rmse:12.57761	validation_1-rmse:13.74337
# [58]	validation_0-rmse:12.52232	validation_1-rmse:13.69374
# [59]	validation_0-rmse:12.46043	validation_1-rmse:13.63138
# [60]	validation_0-rmse:12.40031	validation_1-rmse:13.57647
# [61]	validation_0-rmse:12.34471	validation_1-rmse:13.52205
# [62]	validation_0-rmse:12.29110	validation_1-rmse:13.48312
# [63]	validation_0-rmse:12.22841	validation_1-rmse:13.41779
# [64]	validation_0-rmse:12.17186	validation_1-rmse:13.35717
# [65]	validation_0-rmse:12.11568	validation_1-rmse:13.29229
# [66]	validation_0-rmse:12.06709	validation_1-rmse:13.24303
# [67]	validation_0-rmse:12.01044	validation_1-rmse:13.18637
# [68]	validation_0-rmse:11.95678	validation_1-rmse:13.13661
# [69]	validation_0-rmse:11.90941	validation_1-rmse:13.08620
# [70]	validation_0-rmse:11.86339	validation_1-rmse:13.03553
# [71]	validation_0-rmse:11.81331	validation_1-rmse:12.98152
# [72]	validation_0-rmse:11.76345	validation_1-rmse:12.93011
# [73]	validation_0-rmse:11.71538	validation_1-rmse:12.88006
# [74]	validation_0-rmse:11.66052	validation_1-rmse:12.83291
# [75]	validation_0-rmse:11.61293	validation_1-rmse:12.78566
# [76]	validation_0-rmse:11.56167	validation_1-rmse:12.73759
# [77]	validation_0-rmse:11.50587	validation_1-rmse:12.68388
# [78]	validation_0-rmse:11.45596	validation_1-rmse:12.63132
# [79]	validation_0-rmse:11.40991	validation_1-rmse:12.57878
# [80]	validation_0-rmse:11.36586	validation_1-rmse:12.53566
# [81]	validation_0-rmse:11.32019	validation_1-rmse:12.50020
# [82]	validation_0-rmse:11.27532	validation_1-rmse:12.45755
# [83]	validation_0-rmse:11.23023	validation_1-rmse:12.42530
# [84]	validation_0-rmse:11.18389	validation_1-rmse:12.38401
# [85]	validation_0-rmse:11.13727	validation_1-rmse:12.34770
# [86]	validation_0-rmse:11.09436	validation_1-rmse:12.30973
# [87]	validation_0-rmse:11.04784	validation_1-rmse:12.26388
# [88]	validation_0-rmse:11.00872	validation_1-rmse:12.24275
# [89]	validation_0-rmse:10.96489	validation_1-rmse:12.20530
# [90]	validation_0-rmse:10.92707	validation_1-rmse:12.17376
# [91]	validation_0-rmse:10.88385	validation_1-rmse:12.12986
# [92]	validation_0-rmse:10.83609	validation_1-rmse:12.08694
# [93]	validation_0-rmse:10.79328	validation_1-rmse:12.04190
# [94]	validation_0-rmse:10.75202	validation_1-rmse:12.01013
# [95]	validation_0-rmse:10.70927	validation_1-rmse:11.96925
# [96]	validation_0-rmse:10.67841	validation_1-rmse:11.93937
# [97]	validation_0-rmse:10.63698	validation_1-rmse:11.89079
# [98]	validation_0-rmse:10.59882	validation_1-rmse:11.85778
# [99]	validation_0-rmse:10.55729	validation_1-rmse:11.81988
# [100]	validation_0-rmse:10.51948	validation_1-rmse:11.78437
# [101]	validation_0-rmse:10.48038	validation_1-rmse:11.74408
# [102]	validation_0-rmse:10.44410	validation_1-rmse:11.70588
# [103]	validation_0-rmse:10.41012	validation_1-rmse:11.67123
# [104]	validation_0-rmse:10.37670	validation_1-rmse:11.63786
# [105]	validation_0-rmse:10.33929	validation_1-rmse:11.59617
# [106]	validation_0-rmse:10.30480	validation_1-rmse:11.55758
# [107]	validation_0-rmse:10.27304	validation_1-rmse:11.52706
# [108]	validation_0-rmse:10.24201	validation_1-rmse:11.49969
# [109]	validation_0-rmse:10.21092	validation_1-rmse:11.46895
# [110]	validation_0-rmse:10.18023	validation_1-rmse:11.43684
# [111]	validation_0-rmse:10.14380	validation_1-rmse:11.39853
# [112]	validation_0-rmse:10.10945	validation_1-rmse:11.37049
# [113]	validation_0-rmse:10.07456	validation_1-rmse:11.33384
# [114]	validation_0-rmse:10.04435	validation_1-rmse:11.30489
# [115]	validation_0-rmse:10.01905	validation_1-rmse:11.28361
# [116]	validation_0-rmse:9.98424	validation_1-rmse:11.24773
# [117]	validation_0-rmse:9.95544	validation_1-rmse:11.21493
# [118]	validation_0-rmse:9.92298	validation_1-rmse:11.17931
# [119]	validation_0-rmse:9.89342	validation_1-rmse:11.15342
# [120]	validation_0-rmse:9.86298	validation_1-rmse:11.11749
# [121]	validation_0-rmse:9.83195	validation_1-rmse:11.08449
# [122]	validation_0-rmse:9.80144	validation_1-rmse:11.05462
# [123]	validation_0-rmse:9.77259	validation_1-rmse:11.02713
# [124]	validation_0-rmse:9.74338	validation_1-rmse:10.99860
# [125]	validation_0-rmse:9.71470	validation_1-rmse:10.97602
# [126]	validation_0-rmse:9.68539	validation_1-rmse:10.95285
# [127]	validation_0-rmse:9.65362	validation_1-rmse:10.92267
# [128]	validation_0-rmse:9.62657	validation_1-rmse:10.88936
# [129]	validation_0-rmse:9.60308	validation_1-rmse:10.86158
# [130]	validation_0-rmse:9.57745	validation_1-rmse:10.84747
# [131]	validation_0-rmse:9.55036	validation_1-rmse:10.83016
# [132]	validation_0-rmse:9.52215	validation_1-rmse:10.80615
# [133]	validation_0-rmse:9.49575	validation_1-rmse:10.78185
# [134]	validation_0-rmse:9.46973	validation_1-rmse:10.75233
# [135]	validation_0-rmse:9.44351	validation_1-rmse:10.73272
# [136]	validation_0-rmse:9.41678	validation_1-rmse:10.72330
# [137]	validation_0-rmse:9.39062	validation_1-rmse:10.70203
# [138]	validation_0-rmse:9.36934	validation_1-rmse:10.68395
# [139]	validation_0-rmse:9.34216	validation_1-rmse:10.67110
# [140]	validation_0-rmse:9.31873	validation_1-rmse:10.64913
# [141]	validation_0-rmse:9.29403	validation_1-rmse:10.62890
# [142]	validation_0-rmse:9.27242	validation_1-rmse:10.60546
# [143]	validation_0-rmse:9.25186	validation_1-rmse:10.59252
# [144]	validation_0-rmse:9.22732	validation_1-rmse:10.56454
# [145]	validation_0-rmse:9.20475	validation_1-rmse:10.54082
# [146]	validation_0-rmse:9.18477	validation_1-rmse:10.51777
# [147]	validation_0-rmse:9.16282	validation_1-rmse:10.49446
# [148]	validation_0-rmse:9.13912	validation_1-rmse:10.47267
# [149]	validation_0-rmse:9.11799	validation_1-rmse:10.45215
# [150]	validation_0-rmse:9.09594	validation_1-rmse:10.42543
# [151]	validation_0-rmse:9.07431	validation_1-rmse:10.41001
# [152]	validation_0-rmse:9.05570	validation_1-rmse:10.38654
# [153]	validation_0-rmse:9.03425	validation_1-rmse:10.36182
# [154]	validation_0-rmse:9.01258	validation_1-rmse:10.33992
# [155]	validation_0-rmse:8.99319	validation_1-rmse:10.31949
# [156]	validation_0-rmse:8.97608	validation_1-rmse:10.30253
# [157]	validation_0-rmse:8.95791	validation_1-rmse:10.28599
# [158]	validation_0-rmse:8.93568	validation_1-rmse:10.26802
# [159]	validation_0-rmse:8.91589	validation_1-rmse:10.24857
# [160]	validation_0-rmse:8.89584	validation_1-rmse:10.22304
# [161]	validation_0-rmse:8.87331	validation_1-rmse:10.20948
# [162]	validation_0-rmse:8.85344	validation_1-rmse:10.19526
# [163]	validation_0-rmse:8.83366	validation_1-rmse:10.17365
# [164]	validation_0-rmse:8.81482	validation_1-rmse:10.15354
# [165]	validation_0-rmse:8.79706	validation_1-rmse:10.13901
# [166]	validation_0-rmse:8.77943	validation_1-rmse:10.12333
# [167]	validation_0-rmse:8.75959	validation_1-rmse:10.10320
# [168]	validation_0-rmse:8.74063	validation_1-rmse:10.08638
# [169]	validation_0-rmse:8.72448	validation_1-rmse:10.06558
# [170]	validation_0-rmse:8.70770	validation_1-rmse:10.05031
# [171]	validation_0-rmse:8.68867	validation_1-rmse:10.03905
# [172]	validation_0-rmse:8.67479	validation_1-rmse:10.02538
# [173]	validation_0-rmse:8.65827	validation_1-rmse:10.01084
# [174]	validation_0-rmse:8.63930	validation_1-rmse:9.99286
# [175]	validation_0-rmse:8.62251	validation_1-rmse:9.97841
# [176]	validation_0-rmse:8.60864	validation_1-rmse:9.96701
# [177]	validation_0-rmse:8.59185	validation_1-rmse:9.94874
# [178]	validation_0-rmse:8.57582	validation_1-rmse:9.93805
# [179]	validation_0-rmse:8.56112	validation_1-rmse:9.92842
# [180]	validation_0-rmse:8.54833	validation_1-rmse:9.91590
# [181]	validation_0-rmse:8.53399	validation_1-rmse:9.89974
# [182]	validation_0-rmse:8.51753	validation_1-rmse:9.88081
# [183]	validation_0-rmse:8.50311	validation_1-rmse:9.87208
# [184]	validation_0-rmse:8.48838	validation_1-rmse:9.85574
# [185]	validation_0-rmse:8.47412	validation_1-rmse:9.84203
# [186]	validation_0-rmse:8.45774	validation_1-rmse:9.82739
# [187]	validation_0-rmse:8.44315	validation_1-rmse:9.81181
# [188]	validation_0-rmse:8.42812	validation_1-rmse:9.79351
# [189]	validation_0-rmse:8.41576	validation_1-rmse:9.78098
# [190]	validation_0-rmse:8.40340	validation_1-rmse:9.77241
# [191]	validation_0-rmse:8.38897	validation_1-rmse:9.75711
# [192]	validation_0-rmse:8.37556	validation_1-rmse:9.73855
# [193]	validation_0-rmse:8.36268	validation_1-rmse:9.72216
# [194]	validation_0-rmse:8.35080	validation_1-rmse:9.71004
# [195]	validation_0-rmse:8.33476	validation_1-rmse:9.70133
# [196]	validation_0-rmse:8.32181	validation_1-rmse:9.69274
# [197]	validation_0-rmse:8.31055	validation_1-rmse:9.68518
# [198]	validation_0-rmse:8.29514	validation_1-rmse:9.68408
# [199]	validation_0-rmse:8.28466	validation_1-rmse:9.67155
# [0]	validation_0-rmse:17.87929	validation_1-rmse:16.84372
# [1]	validation_0-rmse:17.76819	validation_1-rmse:16.72292
# [2]	validation_0-rmse:17.66288	validation_1-rmse:16.59859
# [3]	validation_0-rmse:17.56318	validation_1-rmse:16.50633
# [4]	validation_0-rmse:17.45542	validation_1-rmse:16.40699
# [5]	validation_0-rmse:17.36143	validation_1-rmse:16.31376
# [6]	validation_0-rmse:17.26429	validation_1-rmse:16.21559
# [7]	validation_0-rmse:17.15681	validation_1-rmse:16.10337
# [8]	validation_0-rmse:17.05773	validation_1-rmse:16.00401
# [9]	validation_0-rmse:16.95525	validation_1-rmse:15.91031
# [10]	validation_0-rmse:16.85804	validation_1-rmse:15.81534
# [11]	validation_0-rmse:16.76192	validation_1-rmse:15.71995
# [12]	validation_0-rmse:16.66495	validation_1-rmse:15.62648
# [13]	validation_0-rmse:16.56597	validation_1-rmse:15.53304
# [14]	validation_0-rmse:16.46730	validation_1-rmse:15.43256
# [15]	validation_0-rmse:16.37031	validation_1-rmse:15.33876
# [16]	validation_0-rmse:16.28078	validation_1-rmse:15.26585
# [17]	validation_0-rmse:16.18807	validation_1-rmse:15.18656
# [18]	validation_0-rmse:16.10059	validation_1-rmse:15.10317
# [19]	validation_0-rmse:16.00694	validation_1-rmse:15.01766
# [20]	validation_0-rmse:15.91806	validation_1-rmse:14.93567
# [21]	validation_0-rmse:15.83076	validation_1-rmse:14.84533
# [22]	validation_0-rmse:15.74056	validation_1-rmse:14.76019
# [23]	validation_0-rmse:15.65344	validation_1-rmse:14.67545
# [24]	validation_0-rmse:15.56836	validation_1-rmse:14.59290
# [25]	validation_0-rmse:15.49029	validation_1-rmse:14.51064
# [26]	validation_0-rmse:15.40980	validation_1-rmse:14.43412
# [27]	validation_0-rmse:15.32577	validation_1-rmse:14.36957
# [28]	validation_0-rmse:15.25042	validation_1-rmse:14.30431
# [29]	validation_0-rmse:15.16609	validation_1-rmse:14.22041
# [30]	validation_0-rmse:15.08891	validation_1-rmse:14.14487
# [31]	validation_0-rmse:15.01594	validation_1-rmse:14.07931
# [32]	validation_0-rmse:14.94210	validation_1-rmse:14.02848
# [33]	validation_0-rmse:14.86694	validation_1-rmse:13.95644
# [34]	validation_0-rmse:14.78940	validation_1-rmse:13.88726
# [35]	validation_0-rmse:14.71604	validation_1-rmse:13.81360
# [36]	validation_0-rmse:14.64552	validation_1-rmse:13.74035
# [37]	validation_0-rmse:14.57089	validation_1-rmse:13.67519
# [38]	validation_0-rmse:14.49951	validation_1-rmse:13.59807
# [39]	validation_0-rmse:14.42794	validation_1-rmse:13.52775
# [40]	validation_0-rmse:14.35636	validation_1-rmse:13.45998
# [41]	validation_0-rmse:14.28736	validation_1-rmse:13.39103
# [42]	validation_0-rmse:14.21763	validation_1-rmse:13.32107
# [43]	validation_0-rmse:14.15353	validation_1-rmse:13.26244
# [44]	validation_0-rmse:14.08978	validation_1-rmse:13.20352
# [45]	validation_0-rmse:14.02288	validation_1-rmse:13.13944
# [46]	validation_0-rmse:13.95754	validation_1-rmse:13.08001
# [47]	validation_0-rmse:13.89252	validation_1-rmse:13.01678
# [48]	validation_0-rmse:13.82996	validation_1-rmse:12.97080
# [49]	validation_0-rmse:13.77163	validation_1-rmse:12.91556
# [50]	validation_0-rmse:13.70485	validation_1-rmse:12.85015
# [51]	validation_0-rmse:13.64193	validation_1-rmse:12.78766
# [52]	validation_0-rmse:13.58565	validation_1-rmse:12.72977
# [53]	validation_0-rmse:13.52011	validation_1-rmse:12.67993
# [54]	validation_0-rmse:13.45550	validation_1-rmse:12.62240
# [55]	validation_0-rmse:13.39485	validation_1-rmse:12.56100
# [56]	validation_0-rmse:13.33083	validation_1-rmse:12.49903
# [57]	validation_0-rmse:13.27707	validation_1-rmse:12.44798
# [58]	validation_0-rmse:13.22212	validation_1-rmse:12.38743
# [59]	validation_0-rmse:13.16696	validation_1-rmse:12.34153
# [60]	validation_0-rmse:13.11078	validation_1-rmse:12.28759
# [61]	validation_0-rmse:13.06312	validation_1-rmse:12.23710
# [62]	validation_0-rmse:13.01171	validation_1-rmse:12.18341
# [63]	validation_0-rmse:12.95830	validation_1-rmse:12.13248
# [64]	validation_0-rmse:12.90957	validation_1-rmse:12.06999
# [65]	validation_0-rmse:12.85299	validation_1-rmse:12.02808
# [66]	validation_0-rmse:12.80410	validation_1-rmse:11.98729
# [67]	validation_0-rmse:12.75505	validation_1-rmse:11.94404
# [68]	validation_0-rmse:12.70407	validation_1-rmse:11.90135
# [69]	validation_0-rmse:12.65323	validation_1-rmse:11.85582
# [70]	validation_0-rmse:12.60139	validation_1-rmse:11.79976
# [71]	validation_0-rmse:12.55356	validation_1-rmse:11.75151
# [72]	validation_0-rmse:12.50536	validation_1-rmse:11.71433
# [73]	validation_0-rmse:12.45954	validation_1-rmse:11.68154
# [74]	validation_0-rmse:12.41193	validation_1-rmse:11.64711
# [75]	validation_0-rmse:12.36727	validation_1-rmse:11.60253
# [76]	validation_0-rmse:12.32201	validation_1-rmse:11.57125
# [77]	validation_0-rmse:12.27348	validation_1-rmse:11.53679
# [78]	validation_0-rmse:12.23144	validation_1-rmse:11.50813
# [79]	validation_0-rmse:12.18781	validation_1-rmse:11.46143
# [80]	validation_0-rmse:12.14680	validation_1-rmse:11.42459
# [81]	validation_0-rmse:12.10354	validation_1-rmse:11.37859
# [82]	validation_0-rmse:12.06161	validation_1-rmse:11.34062
# [83]	validation_0-rmse:12.02279	validation_1-rmse:11.31538
# [84]	validation_0-rmse:11.97861	validation_1-rmse:11.29021
# [85]	validation_0-rmse:11.93667	validation_1-rmse:11.25999
# [86]	validation_0-rmse:11.89776	validation_1-rmse:11.22650
# [87]	validation_0-rmse:11.86222	validation_1-rmse:11.19205
# [88]	validation_0-rmse:11.82409	validation_1-rmse:11.15775
# [89]	validation_0-rmse:11.78267	validation_1-rmse:11.12714
# [90]	validation_0-rmse:11.74561	validation_1-rmse:11.09199
# [91]	validation_0-rmse:11.70844	validation_1-rmse:11.06668
# [92]	validation_0-rmse:11.67017	validation_1-rmse:11.03107
# [93]	validation_0-rmse:11.63482	validation_1-rmse:10.99803
# [94]	validation_0-rmse:11.59588	validation_1-rmse:10.96178
# [95]	validation_0-rmse:11.55998	validation_1-rmse:10.94358
# [96]	validation_0-rmse:11.53436	validation_1-rmse:10.93117
# [97]	validation_0-rmse:11.50397	validation_1-rmse:10.89898
# [98]	validation_0-rmse:11.46565	validation_1-rmse:10.87613
# [99]	validation_0-rmse:11.42904	validation_1-rmse:10.85046
# [100]	validation_0-rmse:11.39690	validation_1-rmse:10.82496
# [101]	validation_0-rmse:11.36244	validation_1-rmse:10.79872
# [102]	validation_0-rmse:11.33496	validation_1-rmse:10.77381
# [103]	validation_0-rmse:11.30628	validation_1-rmse:10.75828
# [104]	validation_0-rmse:11.27585	validation_1-rmse:10.72707
# [105]	validation_0-rmse:11.24829	validation_1-rmse:10.70397
# [106]	validation_0-rmse:11.21499	validation_1-rmse:10.67610
# [107]	validation_0-rmse:11.18388	validation_1-rmse:10.64708
# [108]	validation_0-rmse:11.14966	validation_1-rmse:10.61495
# [109]	validation_0-rmse:11.11680	validation_1-rmse:10.57968
# [110]	validation_0-rmse:11.08749	validation_1-rmse:10.55097
# [111]	validation_0-rmse:11.05685	validation_1-rmse:10.52241
# [112]	validation_0-rmse:11.02460	validation_1-rmse:10.50677
# [113]	validation_0-rmse:10.99437	validation_1-rmse:10.48057
# [114]	validation_0-rmse:10.96808	validation_1-rmse:10.46571
# [115]	validation_0-rmse:10.93829	validation_1-rmse:10.44158
# [116]	validation_0-rmse:10.90836	validation_1-rmse:10.42210
# [117]	validation_0-rmse:10.88210	validation_1-rmse:10.40257
# [118]	validation_0-rmse:10.85305	validation_1-rmse:10.37637
# [119]	validation_0-rmse:10.82613	validation_1-rmse:10.35345
# [120]	validation_0-rmse:10.79857	validation_1-rmse:10.33020
# [121]	validation_0-rmse:10.76519	validation_1-rmse:10.30029
# [122]	validation_0-rmse:10.73450	validation_1-rmse:10.27822
# [123]	validation_0-rmse:10.70393	validation_1-rmse:10.25862
# [124]	validation_0-rmse:10.67381	validation_1-rmse:10.23639
# [125]	validation_0-rmse:10.64992	validation_1-rmse:10.22191
# [126]	validation_0-rmse:10.62606	validation_1-rmse:10.20128
# [127]	validation_0-rmse:10.59819	validation_1-rmse:10.18021
# [128]	validation_0-rmse:10.57299	validation_1-rmse:10.15944
# [129]	validation_0-rmse:10.55211	validation_1-rmse:10.14535
# [130]	validation_0-rmse:10.52961	validation_1-rmse:10.13430
# [131]	validation_0-rmse:10.50226	validation_1-rmse:10.11923
# [132]	validation_0-rmse:10.47709	validation_1-rmse:10.09621
# [133]	validation_0-rmse:10.44604	validation_1-rmse:10.08164
# [134]	validation_0-rmse:10.42384	validation_1-rmse:10.06559
# [135]	validation_0-rmse:10.40795	validation_1-rmse:10.05922
# [136]	validation_0-rmse:10.37492	validation_1-rmse:10.03802
# [137]	validation_0-rmse:10.35348	validation_1-rmse:10.02903
# [138]	validation_0-rmse:10.33313	validation_1-rmse:10.01638
# [139]	validation_0-rmse:10.31044	validation_1-rmse:10.00539
# [140]	validation_0-rmse:10.28836	validation_1-rmse:9.98995
# [141]	validation_0-rmse:10.26961	validation_1-rmse:9.98127
# [142]	validation_0-rmse:10.25094	validation_1-rmse:9.96251
# [143]	validation_0-rmse:10.22825	validation_1-rmse:9.94154
# [144]	validation_0-rmse:10.19898	validation_1-rmse:9.92038
# [145]	validation_0-rmse:10.18258	validation_1-rmse:9.90913
# [146]	validation_0-rmse:10.16408	validation_1-rmse:9.89426
# [147]	validation_0-rmse:10.14324	validation_1-rmse:9.87816
# [148]	validation_0-rmse:10.12258	validation_1-rmse:9.86366
# [149]	validation_0-rmse:10.10075	validation_1-rmse:9.85181
# [150]	validation_0-rmse:10.08133	validation_1-rmse:9.83539
# [151]	validation_0-rmse:10.05893	validation_1-rmse:9.81715
# [152]	validation_0-rmse:10.04101	validation_1-rmse:9.80523
# [153]	validation_0-rmse:10.02309	validation_1-rmse:9.79201
# [154]	validation_0-rmse:10.00415	validation_1-rmse:9.77907
# [155]	validation_0-rmse:9.98217	validation_1-rmse:9.76792
# [156]	validation_0-rmse:9.95661	validation_1-rmse:9.74621
# [157]	validation_0-rmse:9.93640	validation_1-rmse:9.73450
# [158]	validation_0-rmse:9.91475	validation_1-rmse:9.71373
# [159]	validation_0-rmse:9.89608	validation_1-rmse:9.70560
# [160]	validation_0-rmse:9.87913	validation_1-rmse:9.70184
# [161]	validation_0-rmse:9.85894	validation_1-rmse:9.68771
# [162]	validation_0-rmse:9.83781	validation_1-rmse:9.67010
# [163]	validation_0-rmse:9.81801	validation_1-rmse:9.65150
# [164]	validation_0-rmse:9.79987	validation_1-rmse:9.64657
# [165]	validation_0-rmse:9.78405	validation_1-rmse:9.64038
# [166]	validation_0-rmse:9.76945	validation_1-rmse:9.62507
# [167]	validation_0-rmse:9.75439	validation_1-rmse:9.62079
# [168]	validation_0-rmse:9.74018	validation_1-rmse:9.61681
# [169]	validation_0-rmse:9.72639	validation_1-rmse:9.60872
# [170]	validation_0-rmse:9.71052	validation_1-rmse:9.60347
# [171]	validation_0-rmse:9.69561	validation_1-rmse:9.59272
# [172]	validation_0-rmse:9.68091	validation_1-rmse:9.58953
# [173]	validation_0-rmse:9.66813	validation_1-rmse:9.57931
# [174]	validation_0-rmse:9.65417	validation_1-rmse:9.56725
# [175]	validation_0-rmse:9.64471	validation_1-rmse:9.56630
# [176]	validation_0-rmse:9.63002	validation_1-rmse:9.55122
# [177]	validation_0-rmse:9.61459	validation_1-rmse:9.54088
# [178]	validation_0-rmse:9.59964	validation_1-rmse:9.53198
# [179]	validation_0-rmse:9.58185	validation_1-rmse:9.51365
# [180]	validation_0-rmse:9.56895	validation_1-rmse:9.51280
# [181]	validation_0-rmse:9.55351	validation_1-rmse:9.50558
# [182]	validation_0-rmse:9.54206	validation_1-rmse:9.49301
# [183]	validation_0-rmse:9.52892	validation_1-rmse:9.49575
# [184]	validation_0-rmse:9.51605	validation_1-rmse:9.48445
# [185]	validation_0-rmse:9.50224	validation_1-rmse:9.47707
# [186]	validation_0-rmse:9.48504	validation_1-rmse:9.47324
# [187]	validation_0-rmse:9.47435	validation_1-rmse:9.46535
# [188]	validation_0-rmse:9.45826	validation_1-rmse:9.45741
# [189]	validation_0-rmse:9.44592	validation_1-rmse:9.44820
# [190]	validation_0-rmse:9.43529	validation_1-rmse:9.44258
# [191]	validation_0-rmse:9.42457	validation_1-rmse:9.44073
# [192]	validation_0-rmse:9.41141	validation_1-rmse:9.43443
# [193]	validation_0-rmse:9.40032	validation_1-rmse:9.43210
# [194]	validation_0-rmse:9.38839	validation_1-rmse:9.42318
# [195]	validation_0-rmse:9.37115	validation_1-rmse:9.42120
# [196]	validation_0-rmse:9.35494	validation_1-rmse:9.41319
# [197]	validation_0-rmse:9.34063	validation_1-rmse:9.40875
# [198]	validation_0-rmse:9.32444	validation_1-rmse:9.39729
# [199]	validation_0-rmse:9.31442	validation_1-rmse:9.39558

# %%
# 
# Plot feature importance for regression
plt.figure(figsize=(12, 8))
sns.barplot(x=health_model.feature_importances_, y=top_features)
plt.title('Feature Importance for Health Index')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('health_feature_importance.png')
plt.close()
logging.info('Saved Health_index feature importance plot.')

plt.figure(figsize=(12, 8))
sns.barplot(x=life_model.feature_importances_, y=top_features)
plt.title('Feature Importance for Life Expectation')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('life_feature_importance.png')
plt.close()
logging.info('Saved Life_expectation feature importance plot.')

# %%
# Summary
logging.info('Training completed. Summary:')
logging.info(f'- Health Index MSE (Test): {health_metrics[0]:.4f}, CV MSE: {health_metrics[1].mean():.4f} ± {health_metrics[1].std():.4f} (Target: ≤50)')
logging.info(f'- Life Expectation MSE (Test): {life_metrics[0]:.4f}, CV MSE: {life_metrics[1].mean():.4f} ± {life_metrics[1].std():.4f} (Target: ≤30)')
print('Training completed. Check model_training.log for details.')
# Out:
# Training completed. Check model_training.log for details.
